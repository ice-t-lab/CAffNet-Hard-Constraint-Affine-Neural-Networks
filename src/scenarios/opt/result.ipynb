# %% [markdown]
# # OPT Results
#
# Build the OPT cross-seed LaTeX table from saved evaluation files. This notebook does not evaluate networks again.

# %%
import sys
from pathlib import Path

import torch

REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "src").is_dir() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from src.utils.result import build_average_table, discover_seeds

torch.set_default_dtype(torch.float64)

RESULT_ROOT = REPO_ROOT / "results" / "opt"
print("Available runs:", sorted(path.name for path in RESULT_ROOT.glob("*") if path.is_dir()))

DIR_NAME = "final"
RUN_DIR = RESULT_ROOT / DIR_NAME
OUTPUT_DIR = RUN_DIR

METHODS = ["Optimizer (IPOPT)", "NN", "HardNet", "CAffNet-FF", "CAffNet-FF (Lite)", "CAffNet-TF"]
# SEEDS = discover_seeds(RUN_DIR) if RUN_DIR.exists() else []
SEEDS = [1, 2, 5, 7, 12]

RUN_DIR
# Out:
# Available runs: ['final']
# PosixPath('/Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final')

# %% [markdown]
# ## Average Table Across Seeds

# %%
table = build_average_table(
    RUN_DIR,
    SEEDS,
    METHODS,
    OUTPUT_DIR,
    metric_rename={
        "Max ineq viol.": ("Ineq viol.", "Max"),
        "Mean ineq viol.": ("Ineq viol.", "Mean"),
        "Num ineq viol. (%)": ("Ineq viol.", "Num (%)"),
        "Max eq viol.": ("Eq viol.", "Max"),
        "Mean eq viol.": ("Eq viol.", "Mean"),
        "Num eq viol. (%)": ("Eq viol.", "Num (%)"),
    },
    column_rename={
        "Ineq viol.": "Inequality violation",
        "Eq viol.": "Equality violation",
    },
    bold_best=True,
)
table
# Out:
# [INFO] Processing /Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final/seed_1
# [INFO] Processing /Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final/seed_2
# [INFO] Processing /Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final/seed_5
# [INFO] Processing /Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final/seed_7
# [INFO] Processing /Users/zhao.yang12/Desktop/Projects/202506_SafeAI/code/CAffNet-Hard-Constraint-Affine-Neural-Networks/results/opt/final/seed_12
# \begin{tabular}{lccccccccc}
# \toprule
# Method & Obj. value & \multicolumn{3}{c}{Inequality violation} & \multicolumn{3}{c}{Equality violation} & $T_{train}$ (ms) & $T_{test}$ (ms) \\
# \cmidrule(lr){3-5}\cmidrule(lr){6-8}
#  &  & Max & Mean & Num (\%) & Max & Mean & Num (\%) &  &  \\
# \midrule
# IPOPT & \textbf{-0.3494} & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & - & 25706.5800 \\
#  & (0.4995) & (0.0000) & (0.0000) & (0.00\%) & (0.0000) & (0.0000) & (0.00\%) & (-) & (8842.83) \\
# NN & -0.1755 & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & 0.0273 & 0.0159 & 100.00\% & \textbf{11.5400} & \textbf{1.1700} \\
#  & (0.6078) & (0.0000) & (0.0000) & (0.00\%) & (0.0016) & (0.0009) & (0.00\%) & (0.22) & (0.12) \\
# HardNet & -0.3183 & 0.0007 & 0.0002 & 1.80\% & 0.0143 & 0.0084 & 99.98\% & 14.8800 & 1.7600 \\
#  & (0.5113) & (0.0008) & (0.0002) & (1.63\%) & (0.0053) & (0.0025) & (0.02\%) & (0.30) & (0.03) \\
# CAffNet-FF & -0.3433 & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & 1334.0500 & 1297.8000 \\
#  & (0.5026) & (0.0000) & (0.0000) & (0.00\%) & (0.0000) & (0.0000) & (0.00\%) & (25.49) & (25.80) \\
# CAffNet-FF (Lite) & -0.3433 & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & 745.5600 & 714.2900 \\
#  & (0.5026) & (0.0000) & (0.0000) & (0.00\%) & (0.0000) & (0.0000) & (0.00\%) & (20.27) & (20.33) \\
# CAffNet-TF & -0.1576 & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & \textbf{0.0000} & \textbf{0.0000} & \textbf{0.00\%} & 1335.9100 & 1298.1300 \\
#  & (0.3653) & (0.0000) & (0.0000) & (0.00\%) & (0.0000) & (0.0000) & (0.00\%) & (24.21) & (24.61) \\
# \bottomrule
# \end{tabular}
#                Method        Obj. value Inequality violation                   \
#                                                          Max             Mean
# 0               IPOPT  \textbf{-0.3494}      \textbf{0.0000}  \textbf{0.0000}
# 1                              (0.4995)             (0.0000)         (0.0000)
# 2                  NN           -0.1755      \textbf{0.0000}  \textbf{0.0000}
# 3                              (0.6078)             (0.0000)         (0.0000)
# 4             HardNet           -0.3183               0.0007           0.0002
# 5                              (0.5113)             (0.0008)         (0.0002)
# 6          CAffNet-FF           -0.3433      \textbf{0.0000}  \textbf{0.0000}
# 7                              (0.5026)             (0.0000)         (0.0000)
# 8   CAffNet-FF (Lite)           -0.3433      \textbf{0.0000}  \textbf{0.0000}
# 9                              (0.5026)             (0.0000)         (0.0000)
# 10         CAffNet-TF           -0.1576      \textbf{0.0000}  \textbf{0.0000}
# 11                             (0.3653)             (0.0000)         (0.0000)
#
#                    Equality violation                                   \
#            Num (%)                Max             Mean         Num (%)
# 0   \textbf{0.00%}    \textbf{0.0000}  \textbf{0.0000}  \textbf{0.00%}
# 1          (0.00%)           (0.0000)         (0.0000)         (0.00%)
# 2   \textbf{0.00%}             0.0273           0.0159         100.00%
# 3          (0.00%)           (0.0016)         (0.0009)         (0.00%)
# 4            1.80%             0.0143           0.0084          99.98%
# 5          (1.63%)           (0.0053)         (0.0025)         (0.02%)
# 6   \textbf{0.00%}    \textbf{0.0000}  \textbf{0.0000}  \textbf{0.00%}
# 7          (0.00%)           (0.0000)         (0.0000)         (0.00%)
# 8   \textbf{0.00%}    \textbf{0.0000}  \textbf{0.0000}  \textbf{0.00%}
# 9          (0.00%)           (0.0000)         (0.0000)         (0.00%)
# 10  \textbf{0.00%}    \textbf{0.0000}  \textbf{0.0000}  \textbf{0.00%}
# 11         (0.00%)           (0.0000)         (0.0000)         (0.00%)
#
#     $T_{train}$ (ms)  $T_{test}$ (ms)
#
# 0                  -       25706.5800
# 1                (-)        (8842.83)
# 2   \textbf{11.5400}  \textbf{1.1700}
# 3             (0.22)           (0.12)
# 4            14.8800           1.7600
# 5             (0.30)           (0.03)
# 6          1334.0500        1297.8000
# 7            (25.49)          (25.80)
# 8           745.5600         714.2900
# 9            (20.27)          (20.33)
# 10         1335.9100        1298.1300
# 11           (24.21)          (24.61)

# %% [markdown]
# Saved outputs:
#
# - `evaluation_all_seeds.csv`
# - `evaluation_all_seeds.tex`
